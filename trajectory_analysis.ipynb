# %%
# %pip install ipympl
# %matplotlib widget

# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#    background-color: transparent !important;
# }
# .jp-OutputArea-output {
#    background-color: transparent;
# }
# .jupyter-matplotlib-header {
#    color: white
# }
# .jupyter-matplotlib-footer {
#    color: white
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#    background-color: transparent !important;
# }
# .jp-OutputArea-output {
#    background-color: transparent;
# }
# .jupyter-matplotlib-header {
#    color: white
# }
# .jupyter-matplotlib-footer {
#    color: white
# }
# </style>

# %%
import numpy as np
from matplotlib import pyplot as plt


trajectory = np.load("Trajectory/trajectory_2025-04-08_10-47-00.npy", allow_pickle=True)
keypoints = np.load("Trajectory/keypoints_2025-04-08_11-00-52.npy", allow_pickle=True)
t = trajectory[:,2]
# hand_1_traj = trajectory[:,0]
# hand_2_traj = trajectory[:,1]
hand_1_traj = keypoints[0]

# %%
print(hand_1_traj)
# Out:
# [[0.5726589560508728 0.9227365255355835]
#  [0.4269007444381714 0.8718376755714417]
#  [0.29526787996292114 0.7443885207176208]
#  [0.1675378978252411 0.5250791311264038]
#  [0.21693731844425201 0.6099731922149658]
#  [0.5595322251319885 0.31916558742523193]
#  [0.5539199709892273 0.19238556921482086]
#  [0.5631978511810303 0.0724887028336525]
#  [0.6404241919517517 0.5413375496864319]
#  [0.670031726360321 0.3637160062789917]
#  [0.4364863336086273 0.498783141374588]
#  [0.4561411738395691 0.3342922627925873]
#  [0.46497276425361633 0.19892673194408417]
#  [0.6173456907272339 0.5432252883911133]
#  [0.5701305270195007 0.47560447454452515]
#  [0.6765285134315491 0.21265050768852234]
#  [0.6804586052894592 0.08548157662153244]
#  [0.7544457316398621 0.6041325926780701]
#  [0.7900789380073547 0.4366341829299927]
#  [0.7762730717658997 0.31405359506607056]
#  [0.789973795413971 0.22982653975486755]]

# %% [markdown]
# <img src="Img/hand_landmarks.jpg" width="800">

# %%
def draw_hand(kp):
    x = kp[:,0]
    y = 1 - kp[:,1]
    plt.scatter(x,y)
    plt.plot(x[0:5],y[0:5])
    idx = [0] + list(range(5,8+1))
    plt.plot(x[idx],y[idx])
    idx = [0] + list(range(9,12+1))
    plt.plot(x[idx],y[idx])
    idx = [0] + list(range(13,16+1))
    plt.plot(x[idx],y[idx])
    idx = [0] + list(range(17,20+1))
    plt.plot(x[idx],y[idx])
    idx = [5,9,13,17]
    plt.plot(x[idx],y[idx])
    plt.xlim(0,1)
    plt.ylim(0,1)

plt.figure()
draw_hand(hand_1_traj)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import cv2

label_path = "../datasets/hand-keypoints/train/labels/IMG_00000001.txt"
img_path = "../datasets/hand-keypoints/train/IMG_00000001.jpg"

with open(label_path, 'r') as f:
    label = f.read().split()

label = np.array(label[5:], np.float32)
label = label.reshape((21,3))
print(label)

plt.figure()
draw_hand(label[:,:-1])
plt.show()
# Out:
# [[0.48309237 0.7163427  2.        ]
#  [0.4174393  0.66344583 2.        ]
#  [0.3837761  0.5823003  2.        ]
#  [0.37617403 0.51013416 2.        ]
#  [0.3530092  0.45548788 2.        ]
#  [0.4384731  0.48338118 2.        ]
#  [0.44120508 0.3922432  2.        ]
#  [0.4463641  0.33998543 2.        ]
#  [0.45189196 0.29424995 2.        ]
#  [0.48612443 0.48160857 2.        ]
#  [0.4931791  0.38341844 2.        ]
#  [0.4972663  0.3229398  2.        ]
#  [0.49901512 0.27144077 2.        ]
#  [0.5287731  0.4980598  2.        ]
#  [0.5356496  0.40958816 2.        ]
#  [0.537923   0.3564436  2.        ]
#  [0.5372802  0.31134337 2.        ]
#  [0.5707579  0.5304221  2.        ]
#  [0.58231276 0.4690352  2.        ]
#  [0.58453715 0.42955136 2.        ]
#  [0.58421284 0.39446247 2.        ]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
