# %%
from ultralytics import YOLO
import torch

torch.cuda.is_available()

# %%
model = YOLO("yolo11n-pose.pt")

results = model.train(data="hand-keypoints.yaml", epochs=5, imgsz=640, device='cuda')
# Out:
# Ultralytics 8.3.99  Python-3.12.2 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
print(results)
# Out:
# ultralytics.utils.metrics.PoseMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x000001DA69DCF9E0>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)', 'Precision-Recall(P)', 'F1-Confidence(P)', 'Precision-Confidence(P)', 'Recall-Confidence(P)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
# ...

# %%
model.save("./Models/gesture_tracker_v0.pt")
